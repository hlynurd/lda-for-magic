# %% [markdown]
# # Finding Magic: The Gathering archetypes with LDA: Code
#
# This notebook is meant as a supplement for [this article](https://medium.com/@hlynurd/finding-magic-the-gathering-archetypes-with-latent-dirichlet-allocation-729112d324a6). The results were obtained by working with [this data](Modern.htm).
# You can try this method on data from other formats as well. There is an API on <a href="https://mtgdecks.net" rel="follow">MTG Decks</a> to access the latest 500 tournament decklists from <a href="https://mtgdecks.net/decks/csv/Standard" rel="follow">Standard</a>, <a href="https://mtgdecks.net/decks/csv/Modern" rel="follow">Modern</a>,
# <a href="https://mtgdecks.net/decks/csv/Legacy" rel="follow">Legacy</a>, <a href="https://mtgdecks.net/decks/csv/Vintage" rel="follow">Vintage</a>, <a href="https://mtgdecks.net/decks/csv/Commander" rel="follow">Commander</a>, <a href="https://mtgdecks.net/decks/csv/Pauper" rel="follow">Pauper</a>, <a href="https://mtgdecks.net/decks/csv/Frontier" rel="follow">Frontier</a>, <a href="https://mtgdecks.net/decks/csv/Peasant" rel="follow">Peasant</a>  or <a href="https://mtgdecks.net/decks/csv/Highlander" rel="follow">Highlander</a>.

# %% [markdown]
# ## Preparing the data
#
# The usual first step of machine learning tasks is making sure that the data is in the right form for our algorithms. The raw data is a csv file where each line represents a decklist. Each line contains a main deck and sideboard:

# %%
with open('Modern.htm', 'r') as f:
    print(f.readline())
# Out:
# "4 Celestial Colonnade 1 Celestial Purge 3 Cryptic Command 2 Detention Sphere 1 Disdainful Stroke 1 Dispel 1 Elspeth, Sun's Champion 2 Field of Ruin 4 Flooded Strand 1 Geist of Saint Traft 2 Ghost Quarter 1 Gideon Jura 2 Gideon of the Trials 1 Gideon, Ally of Zendikar 3 Glacial Fortress 1 Grafdigger's Cage 1 Hallowed Fountain 5 Island 1 Jace, Architect of Thought 3 Leyline of Sanctity 3 Mana Leak 2 Negate 4 Path to Exile 3 Plains 2 Rest in Peace 1 Search for Azcanta 4 Serum Visions 3 Snapcaster Mage 1 Sphinx's Revelation 4 Spreading Seas 2 Stony Silence 3 Supreme Verdict 1 Temple of Enlightenment 1 Think Twice 1 Vendilion Clique"

# %% [markdown]
# We feed the data into a gensim Dictionary, similarly as in [this tutorial](https://radimrehurek.com/gensim/tut1.html). We split each decklist into individual cards, ignoring the card counts and cards that appear only once.

# %%
import gensim
import re 
from six import iteritems
# Out:
# Using TensorFlow backend.

# %%
dictionary = gensim.corpora.Dictionary([x.strip() for x in re.split(r"[\d]+", line.replace("\"", ""))] for line in open('Modern.htm'))
once_ids = [tokenid for tokenid, docfreq in iteritems(dictionary.dfs) if docfreq == 1]
dictionary.filter_tokens(once_ids)  # remove cards that appear only once
dictionary.compactify()  # remove gaps in id sequence after words that were removed

# %% [markdown]
# There are almost 700 cards in our modern-card dictionary:

# %%
unique_cards = len(dictionary.keys())
print(unique_cards)
# Out:
# 698

# %% [markdown]
# Next we create a gensim Corpus. Instead of having a bag of words (cards) model, we take note how many times each card appears in a deck and "uncompress" the decklist description.

# %%
import numpy as np

# %%
class MyCorpus(object):
    def __iter__(self):
        for line in open('Modern.htm'):
            decklist = line.replace("\"", "") # remove start and end tokens            
            decklist = re.split(r"([\d]+)", decklist) # split by numbers and card names
            decklist = [x.strip() for x in decklist] # remove whitespace
            decklist = filter(None, decklist) # remove empty words
            cleaned_decklist = [] 
            for i in range(len(decklist)/2): # remove numbers, add multiplicities of cards
                for j in range(int(decklist[i*2])):
                    cleaned_decklist.append(decklist[i*2+1])
            yield dictionary.doc2bow(cleaned_decklist)
corpus_memory_friendly = MyCorpus()

# %% [markdown]
# ## Training the model
# Now that the data is ready, we set the number of achetypes to be found. Setting it to 30 gave me good results. Try varying this and see what happens!

# %%
archetypes = 30

# %% [markdown]
# Since there are stochastic steps in the training of the model, you might get slightly different results each time. Having the seed set to 1 allows you to recreate my results.

# %%
np.random.seed(1)

# %% [markdown]
# The "Latent Dirichlet" part of the method name comes from the assumption that the latent [priors](https://en.wikipedia.org/wiki/Prior_probability) on the per-archetype card distribution and per-decklist archetype distributions are [Dirichlet](https://en.wikipedia.org/wiki/Dirichlet_distribution). This allows us to steer the learning of the model.
#
# By incorporating such priors, we can tell the model how we believe the data actually looks like. If we have a large number of archetypes and are confident that each decklist only falls under one archetype, then setting a low alpha indicates that we prefer each decklist to belong to few, dominating archetypes. We can similarly control the archetype-card sparsity with beta.

# %%
alpha_prior = [1.0 / archetypes] * archetypes
beta_prior = [1.0 / archetypes] * unique_cards

# %% [markdown]
# We finally train the model. This could take a couple of minutes.

# %%
iterations = 30
lda = gensim.models.ldamodel.LdaModel(corpus=corpus_memory_friendly, id2word=dictionary, num_topics=archetypes, passes=iterations, alpha = alpha_prior, eta = beta_prior)

# %% [markdown]
# ## Checking the results
# A good rule of thumb while doing machine learning work is to do regular sanity checks. Anything from simple output prints to beautiful visualizations will help you understand what's going on. After the training is finished, we can explore the archetypes that it finds. Gensim offers a nice way to see the probability-card pairs in each archetype.

# %%
number_of_top_cards = 16
archetypes_to_inspect = 3
for i in range(archetypes_to_inspect):
    print(("Archetype %i \n %s \n") % (i, lda.print_topic(i, topn=number_of_top_cards)))
# Out:
# Archetype 0
#  0.149*"Plains" + 0.064*"Path to Exile" + 0.049*"Thalia, Guardian of Thraben" + 0.048*"Ghost Quarter" + 0.047*"Restoration Angel" + 0.046*"Aether Vial" + 0.044*"Flickerwisp" + 0.041*"Blade Splicer" + 0.039*"Thraben Inspector" + 0.036*"Stony Silence" + 0.034*"Tectonic Edge" + 0.033*"Leonin Arbiter" + 0.032*"Rest in Peace" + 0.028*"Horizon Canopy" + 0.022*"Leyline of Sanctity" + 0.020*"Mirran Crusader"
#
# Archetype 1
#  0.078*"Mountain" + 0.060*"Primeval Titan" + 0.046*"Wooded Foothills" + 0.045*"Search for Tomorrow" + 0.045*"Sakura-Tribe Elder" + 0.044*"Valakut, the Molten Pinnacle" + 0.041*"Stomping Ground" + 0.039*"Scapeshift" + 0.036*"Summoner's Pact" + 0.035*"Farseek" + 0.034*"Forest" + 0.034*"Relic of Progenitus" + 0.033*"Lightning Bolt" + 0.032*"Cinder Glade" + 0.029*"Anger of the Gods" + 0.028*"Obstinate Baloth"
#
# Archetype 2
#  0.055*"Knight of the Reliquary" + 0.054*"Noble Hierarch" + 0.054*"Windswept Heath" + 0.052*"Collected Company" + 0.048*"Path to Exile" + 0.045*"Birds of Paradise" + 0.040*"Forest" + 0.035*"Voice of Resurgence" + 0.031*"Ghost Quarter" + 0.029*"Temple Garden" + 0.025*"Spell Queller" + 0.024*"Courser of Kruphix" + 0.023*"Plains" + 0.022*"Scavenging Ooze" + 0.021*"Selfless Spirit" + 0.020*"Wooded Foothills"

# %% [markdown]
# Since the model is generative, we can generate new decks as well. Here's an example of how to make a metagame altering affinity deck:

# %%
archetype_id = 13
archetype_topic = np.array(lda.show_topic(archetype_id, topn=9999))

archetype_distribution = np.array(archetype_topic[:,1], dtype="float32")
archetype_distribution = archetype_distribution / np.sum(archetype_distribution)

archetype_indices = np.zeros(len(archetype_distribution))
main_deck = 60
sideboard = 15
while np.sum(archetype_indices) < main_deck+sideboard:
    new_card = np.random.multinomial(1, archetype_distribution)
    archetype_indices += new_card
    if 5 in archetype_indices:
        archetype_indices -= new_card
archetype_cards = np.array(archetype_topic[:,0], dtype="string")
minimum_cards = 1.0
deck_title = "Affinity for AI"
print(deck_title)
for i in range(len(archetype_distribution)):
    if archetype_indices[i] >= minimum_cards:        
        print('%i %s' % (archetype_indices[i], archetype_cards[i]))
# Out:
# Affinity for AI
# 4 Blinkmoth Nexus
# 4 Darksteel Citadel
# 4 Mox Opal
# 4 Signal Pest
# 4 Inkmoth Nexus
# 4 Arcbound Ravager
# 4 Cranial Plating
# 4 Ornithopter
# 4 Springleaf Drum
# 4 Vault Skirge
# 4 Steel Overseer
# 4 Etched Champion
# 3 Galvanic Blast
# 2 Master of Etherium
# 3 Spire of Industry
# 1 Memnite
# 3 Ghirapur Aether Grid
# 2 Ancient Grudge
# 3 Glimmervoid
# 2 Grafdigger's Cage
# 2 Spell Pierce
# 1 Whipflare
# 1 Rest in Peace
# 2 Relic of Progenitus
# 1 Vandalblast
# 1 Gemstone Caverns

# %%
import numpy as np
#np.set_printoptions(formatter={'float': lambda x: "{0:0.2f}".format(x)})
#print(topic[i, 0])
#print(topic[i, 1])
#probs = np.array(np.array(lda.show_topic(0, topn=9999))[:,1], dtype="float32")
#print(np.sum(probs))
for j in range(30):
    print("Archetype %i " % (j))
    for i in range(32):
        topic = np.array(lda.show_topic(j, topn=9999))
        print('%.3f %s' % (float(topic[i, 1]), topic[i, 0]))
    print("\n")
# Out:
# Archetype 0
# 0.149 Plains
# 0.064 Path to Exile
# 0.049 Thalia, Guardian of Thraben
# 0.048 Ghost Quarter
# 0.047 Restoration Angel
# 0.046 Aether Vial
# 0.044 Flickerwisp
# 0.041 Blade Splicer
# 0.039 Thraben Inspector
# 0.036 Stony Silence
# 0.034 Tectonic Edge
# 0.033 Leonin Arbiter
# 0.032 Rest in Peace
# 0.028 Horizon Canopy
# 0.022 Leyline of Sanctity
# 0.020 Mirran Crusader
# 0.013 Leonin Abunas
# 0.013 Dusk/Dawn
# 0.012 Burrenton Forge-Tender
# 0.010 Blessed Alliance
# 0.010 Phyrexian Revoker
# 0.010 Serra Avenger
# 0.010 Eiganjo Castle
# 0.008 Sunlance
# 0.008 Kor Firewalker
# 0.008 Selfless Spirit
# 0.007 Grafdigger's Cage
# 0.007 Linvala, Keeper of Silence
# 0.007 Kitchen Finks
# 0.007 Aven Mindcensor
# 0.007 Relic of Progenitus
# 0.007 Thalia, Heretic Cathar
#
#
# Archetype 1
# 0.078 Mountain
# 0.060 Primeval Titan
# 0.046 Wooded Foothills
# 0.045 Search for Tomorrow
# 0.045 Sakura-Tribe Elder
# 0.044 Valakut, the Molten Pinnacle
# 0.041 Stomping Ground
# 0.039 Scapeshift
# 0.036 Summoner's Pact
# 0.035 Farseek
# 0.034 Forest
# 0.034 Relic of Progenitus
# 0.033 Lightning Bolt
# 0.032 Cinder Glade
# 0.029 Anger of the Gods
# 0.028 Obstinate Baloth
# 0.027 Explore
# 0.017 Hour of Promise
# 0.016 Reclamation Sage
# 0.015 Windswept Heath
# 0.013 Leyline of Sanctity
# 0.013 Ancient Grudge
# 0.012 Prismatic Omen
# 0.012 Tireless Tracker
# 0.010 Wrath of God
# 0.010 Nature's Claim
# 0.009 Mwonvuli Acid-Moss
# 0.009 Engineered Explosives
# 0.008 Bloodstained Mire
# 0.008 Chalice of the Void
# 0.008 Thragtusk
# 0.008 Thalia's Lancers
#
#
# Archetype 2
# 0.055 Knight of the Reliquary
# 0.054 Noble Hierarch
# 0.054 Windswept Heath
# 0.052 Collected Company
# 0.048 Path to Exile
# 0.045 Birds of Paradise
# 0.040 Forest
# 0.035 Voice of Resurgence
# 0.031 Ghost Quarter
# 0.029 Temple Garden
# 0.025 Spell Queller
# 0.024 Courser of Kruphix
# 0.023 Plains
# 0.022 Scavenging Ooze
# 0.021 Selfless Spirit
# 0.020 Wooded Foothills
# 0.020 Qasali Pridemage
# 0.019 Misty Rainforest
# 0.019 Tireless Tracker
# 0.015 Horizon Canopy
# 0.015 Kitchen Finks
# 0.014 Stony Silence
# 0.013 Ramunap Excavator
# 0.013 Kataki, War's Wage
# 0.013 Gavony Township
# 0.012 Aven Mindcensor
# 0.011 Mirran Crusader
# 0.011 Eternal Witness
# 0.011 Flooded Strand
# 0.009 Leyline of Sanctity
# 0.009 Island
# 0.009 Retreat to Coralhelm
#
#
# Archetype 3
# 0.060 Insolent Neonate
# 0.055 Cathartic Reunion
# 0.054 Faithless Looting
# 0.051 Narcomoeba
# 0.051 Stinkweed Imp
# 0.051 Prized Amalgam
# 0.051 Bloodghast
# 0.046 Life from the Loam
# 0.042 Collective Brutality
# 0.041 Copperline Gorge
# 0.037 Conflagrate
# 0.031 Gemstone Mine
# 0.029 Golgari Thug
# 0.027 Darkblast
# 0.026 Lightning Axe
# 0.026 Dakmor Salvage
# 0.025 Ancient Grudge
# 0.025 Wooded Foothills
# 0.024 Mountain
# 0.023 Abrupt Decay
# 0.020 Stomping Ground
# 0.018 Arid Mesa
# 0.017 Blood Crypt
# 0.017 Nature's Claim
# 0.014 Mana Confluence
# 0.011 City of Brass
# 0.011 Gnaw to the Bone
# 0.010 Bloodstained Mire
# 0.010 Vengeful Pharaoh
# 0.010 Ghost Quarter
# 0.009 Thoughtseize
# 0.008 Scalding Tarn
#
#
# Archetype 4
# 0.065 Simian Spirit Guide
# 0.043 Street Wraith
# 0.042 Blackcleave Cliffs
# 0.041 Monstrous Carabid
# 0.041 Violent Outburst
# 0.041 Demonic Dread
# 0.041 Horror of the Broken Lands
# 0.038 Fulminator Mage
# 0.038 Beast Within
# 0.034 Shrine of Burning Rage
# 0.034 Ricochet Trap
# 0.031 Living End
# 0.031 Ingot Chewer
# 0.029 Bloodstained Mire
# 0.027 Leyline of the Void
# 0.027 Chained to the Rocks
# 0.027 Desert Cerodon
# 0.027 Deadshot Minotaur
# 0.025 Verdant Catacombs
# 0.025 Blooming Marsh
# 0.024 Faerie Macabre
# 0.024 Shriekmaw
# 0.021 Wear/Tear
# 0.017 Swamp
# 0.016 Wooded Foothills
# 0.014 Lost Legacy
# 0.011 Overgrown Tomb
# 0.011 Stomping Ground
# 0.011 Blood Crypt
# 0.010 Pyroclasm
# 0.008 Mountain
# 0.008 Forest
#
#
# Archetype 5
# 0.061 Island
# 0.037 Urza's Power Plant
# 0.037 Urza's Tower
# 0.037 Expedition Map
# 0.037 Urza's Mine
# 0.035 Condescend
# 0.033 Thirst for Knowledge
# 0.022 Grove of the Burnwillows
# 0.022 Repeal
# 0.020 Wurmcoil Engine
# 0.020 Talisman of Dominance
# 0.020 Spatial Contortion
# 0.019 Remand
# 0.019 Polluted Delta
# 0.018 Mesmeric Orb
# 0.018 Glimpse the Unthinkable
# 0.018 Hedron Crab
# 0.018 Manic Scribe
# 0.017 Dismember
# 0.016 Ghost Quarter
# 0.015 Visions of Beyond
# 0.014 Ugin, the Spirit Dragon
# 0.013 Tormod's Crypt
# 0.013 Fraying Sanity
# 0.013 Mind Funeral
# 0.013 Oblivion Stone
# 0.013 Chalice of the Void
# 0.012 Karn Liberated
# 0.012 Spellskite
# 0.012 Watery Grave
# 0.011 Hurkyl's Recall
# 0.011 Mindslaver
#
#
# Archetype 6
# 0.263 Swamp
# 0.059 Duress
# 0.052 Raven's Crime
# 0.041 Gifted Aetherborn
# 0.040 Mutavault
# 0.039 Ghost Quarter
# 0.033 Tormod's Crypt
# 0.032 Inquisition of Kozilek
# 0.031 Smallpox
# 0.030 Smuggler's Copter
# 0.030 Delirium Skeins
# 0.030 Shrieking Affliction
# 0.030 The Rack
# 0.022 Wrench Mind
# 0.019 Sign in Blood
# 0.019 Gurmag Angler
# 0.015 Darkblast
# 0.015 Dakmor Salvage
# 0.015 Chameleon Colossus
# 0.015 Go for the Throat
# 0.014 Relic of Progenitus
# 0.011 Fatal Push
# 0.008 Shadow of Doubt
# 0.008 Dragon's Claw
# 0.008 Gonti, Lord of Luxury
# 0.008 Doom Blade
# 0.008 Tombstalker
# 0.007 Dismember
# 0.004 Grafdigger's Cage
# 0.004 Flooded Strand
# 0.004 Elspeth, Sun's Champion
# 0.004 Twilight Mire
#
#
# Archetype 7
# 0.065 Island
# 0.056 Path to Exile
# 0.052 Flooded Strand
# 0.051 Celestial Colonnade
# 0.048 Supreme Verdict
# 0.047 Spreading Seas
# 0.040 Serum Visions
# 0.039 Cryptic Command
# 0.039 Plains
# 0.033 Snapcaster Mage
# 0.033 Field of Ruin
# 0.029 Stony Silence
# 0.026 Glacial Fortress
# 0.024 Mana Leak
# 0.024 Negate
# 0.024 Detention Sphere
# 0.023 Gideon of the Trials
# 0.022 Hallowed Fountain
# 0.021 Rest in Peace
# 0.017 Ghost Quarter
# 0.015 Wall of Omens
# 0.014 Vendilion Clique
# 0.014 Gideon Jura
# 0.013 Jace, Architect of Thought
# 0.013 Timely Reinforcements
# 0.013 Search for Azcanta
# 0.012 Dispel
# 0.012 Blessed Alliance
# 0.011 Sphinx's Revelation
# 0.011 Elspeth, Sun's Champion
# 0.011 Disdainful Stroke
# 0.010 Surgical Extraction
#
#
# Archetype 8
# 0.064 Polluted Delta
# 0.050 Snapcaster Mage
# 0.045 Flooded Strand
# 0.043 Island
# 0.041 Opt
# 0.039 Mana Leak
# 0.036 Fatal Push
# 0.035 Lingering Souls
# 0.033 Cryptic Command
# 0.032 Watery Grave
# 0.022 Vendilion Clique
# 0.022 Darkslick Shores
# 0.021 Ceremonious Rejection
# 0.021 Collective Brutality
# 0.020 Spell Snare
# 0.019 Creeping Tar Pit
# 0.019 Logic Knot
# 0.018 Blessed Alliance
# 0.017 Tasigur, the Golden Fang
# 0.017 Search for Azcanta
# 0.017 Negate
# 0.017 Thought Scour
# 0.015 Esper Charm
# 0.015 Swamp
# 0.014 Inquisition of Kozilek
# 0.013 Dispel
# 0.013 Hallowed Fountain
# 0.013 Path to Exile
# 0.012 Bitterblossom
# 0.011 Thoughtseize
# 0.011 Godless Shrine
# 0.010 Engineered Explosives
#
#
# Archetype 9
# 0.049 Monastery Swiftspear
# 0.048 Lightning Helix
# 0.045 Lightning Bolt
# 0.044 Goblin Guide
# 0.042 Eidolon of the Great Revel
# 0.041 Boros Charm
# 0.040 Lava Spike
# 0.040 Wooded Foothills
# 0.040 Rift Bolt
# 0.038 Bloodstained Mire
# 0.038 Searing Blaze
# 0.037 Skullcrack
# 0.034 Mountain
# 0.032 Inspiring Vantage
# 0.028 Arid Mesa
# 0.027 Sacred Foundry
# 0.024 Path to Exile
# 0.023 Destructive Revelry
# 0.018 Simian Spirit Guide
# 0.016 Deflecting Palm
# 0.013 Searing Blood
# 0.013 Leyline of Sanctity
# 0.012 Scalding Tarn
# 0.012 Kor Firewalker
# 0.011 Grim Lavamancer
# 0.011 Rest in Peace
# 0.011 Pact of Negation
# 0.011 Ad Nauseam
# 0.011 Angel's Grace
# 0.011 Temple of Deceit
# 0.011 Smash to Smithereens
# 0.010 Lotus Bloom
#
#
# Archetype 10
# 0.069 Nahiri, the Harbinger
# 0.049 Windswept Heath
# 0.034 Eldrazi Displacer
# 0.034 Noble Hierarch
# 0.031 Path to Exile
# 0.030 Ancient Stirrings
# 0.029 Leyline of Sanctity
# 0.027 Reality Smasher
# 0.027 Eldrazi Temple
# 0.027 Thought-Knot Seer
# 0.025 Eldrazi Skyspawner
# 0.025 Drowner of Hope
# 0.024 Rest in Peace
# 0.021 Birds of Paradise
# 0.021 Engineered Explosives
# 0.019 Cavern of Souls
# 0.018 Forest
# 0.018 Utopia Sprawl
# 0.018 Arbor Elf
# 0.017 Wooded Foothills
# 0.017 Restoration Angel
# 0.017 Wall of Omens
# 0.017 Breeding Pool
# 0.017 Stubborn Denial
# 0.017 Emrakul, the Aeons Torn
# 0.016 Stony Silence
# 0.016 Temple Garden
# 0.013 Stomping Ground
# 0.013 Yavimaya Coast
# 0.013 Fertile Ground
# 0.013 Talisman of Progress
# 0.013 Primal Command
#
#
# Archetype 11
# 0.053 Cavern of Souls
# 0.053 Unclaimed Territory
# 0.053 Champion of the Parish
# 0.053 Thalia's Lieutenant
# 0.053 Kitesail Freebooter
# 0.053 Meddling Mage
# 0.052 Reflector Mage
# 0.051 Thalia, Guardian of Thraben
# 0.050 Noble Hierarch
# 0.047 Mantis Rider
# 0.045 Ancient Ziggurat
# 0.044 Aether Vial
# 0.039 Mayor of Avabruck
# 0.033 Windswept Heath
# 0.026 Izzet Staticaster
# 0.024 Horizon Canopy
# 0.023 Thalia, Heretic Cathar
# 0.022 Vithian Renegades
# 0.022 Xathrid Necromancer
# 0.020 Fiend Hunter
# 0.019 Dark Confidant
# 0.017 Ethersworn Canonist
# 0.015 Plains
# 0.012 Tireless Tracker
# 0.011 Hallowed Fountain
# 0.011 Temple Garden
# 0.010 Mirran Crusader
# 0.009 Avacyn's Pilgrim
# 0.008 Anafenza, the Foremost
# 0.006 Kambal, Consul of Allocation
# 0.005 Stony Silence
# 0.005 Sin Collector
#
#
# Archetype 12
# 0.068 Path to Exile
# 0.050 Razorverge Thicket
# 0.048 Windswept Heath
# 0.044 Daybreak Coronet
# 0.044 Rancor
# 0.044 Ethereal Armor
# 0.044 Leyline of Sanctity
# 0.044 Slippery Bogle
# 0.044 Gladecover Scout
# 0.044 Kor Spiritdancer
# 0.039 Wooded Foothills
# 0.035 Temple Garden
# 0.033 Spider Umbra
# 0.030 Rest in Peace
# 0.028 Stony Silence
# 0.022 Horizon Canopy
# 0.022 Aether Hub
# 0.022 Seal of Primordium
# 0.022 Gryff's Boon
# 0.022 Spirit Mantle
# 0.022 Blessed Alliance
# 0.019 Forest
# 0.017 Plains
# 0.017 Gaddock Teeg
# 0.011 Dryad Arbor
# 0.011 Suppression Field
# 0.011 Natural State
# 0.006 Unclaimed Territory
# 0.006 Worship
# 0.006 Geier Reach Sanitarium
# 0.000 Relic of Progenitus
# 0.000 Matter Reshaper
#
#
# Archetype 13
# 0.055 Blinkmoth Nexus
# 0.055 Darksteel Citadel
# 0.053 Mox Opal
# 0.053 Signal Pest
# 0.053 Inkmoth Nexus
# 0.053 Arcbound Ravager
# 0.053 Cranial Plating
# 0.053 Ornithopter
# 0.052 Springleaf Drum
# 0.050 Vault Skirge
# 0.049 Steel Overseer
# 0.046 Etched Champion
# 0.040 Galvanic Blast
# 0.034 Master of Etherium
# 0.033 Spire of Industry
# 0.031 Memnite
# 0.026 Ghirapur Aether Grid
# 0.022 Thoughtseize
# 0.018 Ancient Grudge
# 0.018 Glimmervoid
# 0.014 Dispatch
# 0.013 Blood Moon
# 0.013 Grafdigger's Cage
# 0.012 Thoughtcast
# 0.011 Spell Pierce
# 0.010 Whipflare
# 0.010 Welding Jar
# 0.010 Mountain
# 0.009 Rest in Peace
# 0.007 Stubborn Denial
# 0.006 Wear/Tear
# 0.005 Rule of Law
#
#
# Archetype 14
# 0.068 Polluted Delta
# 0.060 Bloodstained Mire
# 0.059 Death's Shadow
# 0.054 Street Wraith
# 0.053 Fatal Push
# 0.050 Stubborn Denial
# 0.049 Thoughtseize
# 0.043 Thought Scour
# 0.042 Serum Visions
# 0.040 Snapcaster Mage
# 0.039 Scalding Tarn
# 0.029 Watery Grave
# 0.028 Terminate
# 0.026 Inquisition of Kozilek
# 0.025 Collective Brutality
# 0.025 Ceremonious Rejection
# 0.024 Kolaghan's Command
# 0.022 Blood Crypt
# 0.022 Gurmag Angler
# 0.021 Tasigur, the Golden Fang
# 0.020 Kozilek's Return
# 0.020 Temur Battle Rage
# 0.019 Disdainful Stroke
# 0.016 Liliana of the Veil
# 0.015 Swamp
# 0.011 Opt
# 0.011 Young Pyromancer
# 0.011 Steam Vents
# 0.011 Izzet Staticaster
# 0.010 Island
# 0.010 Nihil Spellbomb
# 0.009 Liliana, the Last Hope
#
#
# Archetype 15
# 0.069 Wooded Foothills
# 0.050 Forest
# 0.039 Windswept Heath
# 0.039 Nykthos, Shrine to Nyx
# 0.035 Burning-Tree Emissary
# 0.034 Arbor Elf
# 0.034 Utopia Sprawl
# 0.027 Garruk Wildspeaker
# 0.027 Stomping Ground
# 0.024 Tarmogoyf
# 0.023 Blood Moon
# 0.020 Kitchen Finks
# 0.020 Narnam Renegade
# 0.020 Oath of Nissa
# 0.017 Atarka's Command
# 0.017 Lightning Bolt
# 0.016 Courser of Kruphix
# 0.016 Goblin Guide
# 0.016 Arid Mesa
# 0.016 Wild Nacatl
# 0.016 Reckless Bushwhacker
# 0.016 Summoner's Pact
# 0.016 Kird Ape
# 0.016 Relic of Progenitus
# 0.016 Birds of Paradise
# 0.015 Misty Rainforest
# 0.014 Path to Exile
# 0.013 Obstinate Baloth
# 0.013 Eternal Witness
# 0.012 Verdant Catacombs
# 0.012 Boros Charm
# 0.012 Wall of Roots
#
#
# Archetype 16
# 0.139 Mountain
# 0.046 Ensnaring Bridge
# 0.042 Ancient Stirrings
# 0.041 Glimmervoid
# 0.041 Mox Opal
# 0.040 Codex Shredder
# 0.040 Whir of Invention
# 0.040 Lantern of Insight
# 0.040 Spire of Industry
# 0.035 Mishra's Bauble
# 0.034 Thoughtseize
# 0.034 Darkslick Shores
# 0.031 Pithing Needle
# 0.028 Leyline of Sanctity
# 0.027 Botanical Sanctum
# 0.025 Inquisition of Kozilek
# 0.024 Collective Brutality
# 0.021 Snow-Covered Mountain
# 0.019 Pyxis of Pandemonium
# 0.018 Welding Jar
# 0.017 Grafdigger's Cage
# 0.017 Abrupt Decay
# 0.014 Witchbane Orb
# 0.014 Academy Ruins
# 0.013 Inventors' Fair
# 0.010 Island
# 0.010 River of Tears
# 0.010 Nature's Claim
# 0.009 Ancient Grudge
# 0.008 Seal of Primordium
# 0.007 Engineered Explosives
# 0.007 Maelstrom Pulse
#
#
# Archetype 17
# 0.077 Island
# 0.065 Lightning Bolt
# 0.058 Remand
# 0.054 Scalding Tarn
# 0.048 Snapcaster Mage
# 0.040 Serum Visions
# 0.039 Steam Vents
# 0.034 Through the Breach
# 0.034 Opt
# 0.033 Blood Moon
# 0.033 Sulfur Falls
# 0.031 Dispel
# 0.031 Cryptic Command
# 0.027 Emrakul, the Aeons Torn
# 0.024 Anger of the Gods
# 0.023 Polluted Delta
# 0.022 Electrolyze
# 0.019 Desolate Lighthouse
# 0.019 Spell Snare
# 0.016 Roast
# 0.016 Delver of Secrets
# 0.016 Mountain
# 0.014 Engineered Explosives
# 0.013 Ceremonious Rejection
# 0.012 Young Pyromancer
# 0.012 Deceiver Exarch
# 0.012 Pestermite
# 0.012 Flooded Strand
# 0.010 Misty Rainforest
# 0.010 Kiki-Jiki, Mirror Breaker
# 0.008 Vendilion Clique
# 0.008 Relic of Progenitus
#
#
# Archetype 18
# 0.056 Lightning Bolt
# 0.055 Path to Exile
# 0.055 Flooded Strand
# 0.054 Scalding Tarn
# 0.054 Snapcaster Mage
# 0.052 Spell Queller
# 0.050 Celestial Colonnade
# 0.046 Serum Visions
# 0.043 Lightning Helix
# 0.041 Cryptic Command
# 0.036 Island
# 0.034 Geist of Saint Traft
# 0.034 Logic Knot
# 0.027 Steam Vents
# 0.027 Hallowed Fountain
# 0.026 Electrolyze
# 0.023 Dispel
# 0.019 Spell Snare
# 0.017 Relic of Progenitus
# 0.016 Disdainful Stroke
# 0.016 Sulfur Falls
# 0.015 Vendilion Clique
# 0.014 Sacred Foundry
# 0.013 Plains
# 0.012 Negate
# 0.012 Izzet Staticaster
# 0.012 Mountain
# 0.011 Supreme Verdict
# 0.011 Pia and Kiran Nalaar
# 0.010 Celestial Purge
# 0.010 Spirebluff Canal
# 0.010 Engineered Explosives
#
#
# Archetype 19
# 0.059 Concealed Courtyard
# 0.058 Tidehollow Sculler
# 0.056 Path to Exile
# 0.052 Caves of Koilos
# 0.049 Thought-Knot Seer
# 0.049 Eldrazi Temple
# 0.046 Ghost Quarter
# 0.045 Aether Vial
# 0.043 Eldrazi Displacer
# 0.043 Leonin Arbiter
# 0.042 Thalia, Guardian of Thraben
# 0.040 Flickerwisp
# 0.039 Wasteland Strangler
# 0.033 Stony Silence
# 0.028 Rest in Peace
# 0.028 Shambling Vent
# 0.027 Plains
# 0.021 Zealous Persecution
# 0.018 Fatal Push
# 0.018 Dark Confidant
# 0.015 Swamp
# 0.014 Godless Shrine
# 0.012 Reality Smasher
# 0.010 Orzhov Pontiff
# 0.010 Blessed Alliance
# 0.009 Mirran Crusader
# 0.008 Relic of Progenitus
# 0.007 Grafdigger's Cage
# 0.007 Kor Firewalker
# 0.007 Burrenton Forge-Tender
# 0.006 Gideon, Ally of Zendikar
# 0.006 Aven Mindcensor
#
#
# Archetype 20
# 0.072 Faithless Looting
# 0.058 Cathartic Reunion
# 0.058 Bloodstained Mire
# 0.057 Hollow One
# 0.056 Street Wraith
# 0.052 Leyline of the Void
# 0.042 Swamp
# 0.035 Mountain
# 0.035 Blood Crypt
# 0.034 Vengevine
# 0.034 Griselbrand
# 0.034 Goryo's Vengeance
# 0.031 Lightning Bolt
# 0.029 Ancient Grudge
# 0.029 Gurmag Angler
# 0.025 Night's Whisper
# 0.025 Thoughtseize
# 0.025 Verdant Catacombs
# 0.023 Bloodghast
# 0.023 Fiery Temper
# 0.023 Flameblade Adept
# 0.023 Burning Inquiry
# 0.017 Blackcleave Cliffs
# 0.017 Dragon's Claw
# 0.015 Stomping Ground
# 0.013 Lightning Axe
# 0.013 Death's Shadow
# 0.011 Flamewake Phoenix
# 0.007 Tarfire
# 0.007 Temur Battle Rage
# 0.003 Fatal Push
# 0.003 Claim/Fame
#
#
# Archetype 21
# 0.099 Island
# 0.055 Mutavault
# 0.050 Ceremonious Rejection
# 0.050 Spreading Seas
# 0.048 Master of the Pearl Trident
# 0.048 Silvergill Adept
# 0.048 Lord of Atlantis
# 0.048 Aether Vial
# 0.044 Merrow Reejerey
# 0.044 Harbinger of the Tides
# 0.044 Relic of Progenitus
# 0.040 Botanical Sanctum
# 0.038 Cavern of Souls
# 0.032 Kumena's Speaker
# 0.032 Merfolk Branchwalker
# 0.032 Cursecatcher
# 0.026 Natural State
# 0.022 Dispel
# 0.020 Dismember
# 0.017 Breeding Pool
# 0.014 Bontu's Last Reckoning
# 0.010 Master of Waves
# 0.010 Kopala, Warden of Waves
# 0.009 Polluted Delta
# 0.008 Echoing Truth
# 0.008 Unified Will
# 0.008 Vapor Snag
# 0.007 Hurkyl's Recall
# 0.006 Grafdigger's Cage
# 0.006 Disdainful Stroke
# 0.006 Kira, Great Glass-Spinner
# 0.006 Unclaimed Territory
#
#
# Archetype 22
# 0.059 Misty Rainforest
# 0.058 Collected Company
# 0.052 Noble Hierarch
# 0.051 Windswept Heath
# 0.050 Devoted Druid
# 0.050 Spell Queller
# 0.048 Chord of Calling
# 0.046 Path to Exile
# 0.039 Vizier of Remedies
# 0.038 Unified Will
# 0.037 Birds of Paradise
# 0.036 Eternal Witness
# 0.036 Duskwatch Recruiter
# 0.029 Breeding Pool
# 0.029 Forest
# 0.025 Burrenton Forge-Tender
# 0.024 Reflector Mage
# 0.024 Geist of Saint Traft
# 0.024 Razorverge Thicket
# 0.020 Gavony Township
# 0.018 Temple Garden
# 0.018 Qasali Pridemage
# 0.017 Walking Ballista
# 0.017 Botanical Sanctum
# 0.015 Hallowed Fountain
# 0.012 Plains
# 0.011 Tireless Tracker
# 0.011 Jace, Vryn's Prodigy
# 0.008 Eidolon of Rhetoric
# 0.008 Scavenging Ooze
# 0.008 Meddling Mage
# 0.005 Flooded Strand
#
#
# Archetype 23
# 0.056 Liliana of the Veil
# 0.056 Inquisition of Kozilek
# 0.054 Verdant Catacombs
# 0.054 Fatal Push
# 0.052 Tarmogoyf
# 0.052 Thoughtseize
# 0.046 Lingering Souls
# 0.036 Marsh Flats
# 0.036 Collective Brutality
# 0.036 Fulminator Mage
# 0.028 Swamp
# 0.025 Abrupt Decay
# 0.025 Blooming Marsh
# 0.025 Overgrown Tomb
# 0.021 Surgical Extraction
# 0.019 Mishra's Bauble
# 0.019 Path to Exile
# 0.019 Dark Confidant
# 0.018 Traverse the Ulvenwald
# 0.018 Godless Shrine
# 0.018 Shambling Vent
# 0.016 Maelstrom Pulse
# 0.015 Scavenging Ooze
# 0.015 Damnation
# 0.014 Stony Silence
# 0.014 Liliana, the Last Hope
# 0.014 Grim Flayer
# 0.011 Nihil Spellbomb
# 0.009 Plains
# 0.009 Windswept Heath
# 0.009 Siege Rhino
# 0.009 Leyline of the Void
#
#
# Archetype 24
# 0.055 Blood Moon
# 0.051 Lightning Bolt
# 0.049 Bloodstained Mire
# 0.048 Blackcleave Cliffs
# 0.047 Forest
# 0.034 Terminate
# 0.032 Kolaghan's Command
# 0.028 Wooded Foothills
# 0.024 Inquisition of Kozilek
# 0.024 Anger of the Gods
# 0.023 Goblin Rabblemaster
# 0.020 Blood Crypt
# 0.020 Stomping Ground
# 0.019 Raging Ravine
# 0.018 Chandra, Torch of Defiance
# 0.018 Thoughtseize
# 0.018 Mountain
# 0.017 Bedlam Reveler
# 0.017 Stone Rain
# 0.017 Faithless Looting
# 0.017 Young Pyromancer
# 0.017 Leyline of the Void
# 0.016 Ancient Grudge
# 0.015 Utopia Sprawl
# 0.015 Arbor Elf
# 0.015 Lingering Souls
# 0.014 Kitchen Finks
# 0.013 Tireless Tracker
# 0.013 Mwonvuli Acid-Moss
# 0.013 Bonfire of the Damned
# 0.013 Fatal Push
# 0.012 Windswept Heath
#
#
# Archetype 25
# 0.052 Chord of Calling
# 0.052 Windswept Heath
# 0.052 Kitchen Finks
# 0.051 Collected Company
# 0.050 Birds of Paradise
# 0.049 Verdant Catacombs
# 0.043 Devoted Druid
# 0.041 Vizier of Remedies
# 0.039 Eternal Witness
# 0.032 Noble Hierarch
# 0.032 Path to Exile
# 0.030 Temple Garden
# 0.029 Forest
# 0.025 Gavony Township
# 0.024 Duskwatch Recruiter
# 0.023 Overgrown Tomb
# 0.022 Horizon Canopy
# 0.022 Razorverge Thicket
# 0.022 Abrupt Decay
# 0.019 Voice of Resurgence
# 0.019 Viscera Seer
# 0.017 Scavenging Ooze
# 0.015 Eidolon of Rhetoric
# 0.013 Plains
# 0.012 Qasali Pridemage
# 0.012 Kataki, War's Wage
# 0.011 Tireless Tracker
# 0.011 Sin Collector
# 0.010 Tidehollow Sculler
# 0.010 Walking Ballista
# 0.010 Selfless Spirit
# 0.009 Godless Shrine
#
#
# Archetype 26
# 0.053 Urza's Mine
# 0.053 Expedition Map
# 0.053 Urza's Tower
# 0.053 Urza's Power Plant
# 0.042 Walking Ballista
# 0.038 Thought-Knot Seer
# 0.036 Karn Liberated
# 0.036 Relic of Progenitus
# 0.034 Chalice of the Void
# 0.034 Matter Reshaper
# 0.034 Eldrazi Temple
# 0.034 Reality Smasher
# 0.028 Ghost Quarter
# 0.025 Warping Wail
# 0.021 Dismember
# 0.021 Wurmcoil Engine
# 0.020 Chromatic Sphere
# 0.020 Chromatic Star
# 0.020 Ancient Stirrings
# 0.019 Sylvan Scrying
# 0.018 All Is Dust
# 0.018 Wastes
# 0.017 Endbringer
# 0.017 Oblivion Stone
# 0.017 Ratchet Bomb
# 0.016 Grafdigger's Cage
# 0.015 Ulamog, the Ceaseless Hunger
# 0.013 Hangarback Walker
# 0.013 Surgical Extraction
# 0.012 Ugin, the Spirit Dragon
# 0.011 Cavern of Souls
# 0.011 Basilisk Collar
#
#
# Archetype 27
# 0.054 Noble Hierarch
# 0.053 Inkmoth Nexus
# 0.053 Glistener Elf
# 0.052 Vines of Vastwood
# 0.052 Mutagenic Growth
# 0.051 Might of Old Krosa
# 0.049 Blighted Agent
# 0.043 Blossoming Defense
# 0.041 Become Immense
# 0.040 Groundswell
# 0.036 Windswept Heath
# 0.030 Verdant Catacombs
# 0.029 Spell Pierce
# 0.027 Misty Rainforest
# 0.026 Breeding Pool
# 0.026 Forest
# 0.026 Pendelhaven
# 0.026 Nature's Claim
# 0.025 Dismember
# 0.023 Wooded Foothills
# 0.023 Spellskite
# 0.019 Apostle's Blessing
# 0.017 Viridian Corrupter
# 0.016 Shapers' Sanctuary
# 0.014 Jace, Vryn's Prodigy
# 0.014 Distortion Strike
# 0.014 Dryad Arbor
# 0.014 Grafdigger's Cage
# 0.012 Dispel
# 0.011 Twisted Image
# 0.010 Relic of Progenitus
# 0.009 Rancor
#
#
# Archetype 28
# 0.051 Serum Visions
# 0.048 Sleight of Hand
# 0.047 Desperate Ritual
# 0.047 Manamorphose
# 0.045 Gifts Ungiven
# 0.045 Pyretic Ritual
# 0.044 Baral, Chief of Compliance
# 0.041 Spirebluff Canal
# 0.039 Island
# 0.036 Steam Vents
# 0.034 Remand
# 0.032 Goblin Electromancer
# 0.032 Lightning Bolt
# 0.031 Grapeshot
# 0.028 Scalding Tarn
# 0.027 Empty the Warrens
# 0.026 Pieces of the Puzzle
# 0.026 Opt
# 0.023 Past in Flames
# 0.017 Shattering Spree
# 0.017 Shivan Reef
# 0.015 Dispel
# 0.014 Dismember
# 0.012 Mountain
# 0.012 Blood Moon
# 0.011 Flooded Strand
# 0.009 Echoing Truth
# 0.009 Gemstone Mine
# 0.009 Noxious Revival
# 0.008 Simic Growth Chamber
# 0.008 Amulet of Vigor
# 0.008 Ancient Stirrings
#
#
# Archetype 29
# 0.052 Forest
# 0.052 Elvish Archdruid
# 0.052 Heritage Druid
# 0.052 Llanowar Elves
# 0.051 Collected Company
# 0.051 Nettle Sentinel
# 0.051 Dwynen's Elite
# 0.051 Elvish Mystic
# 0.049 Chord of Calling
# 0.042 Ezuri, Renegade Leader
# 0.039 Windswept Heath
# 0.033 Elvish Visionary
# 0.031 Razorverge Thicket
# 0.030 Devoted Druid
# 0.028 Path to Exile
# 0.024 Cavern of Souls
# 0.021 Shaman of the Pack
# 0.018 Scavenging Ooze
# 0.017 Horizon Canopy
# 0.014 Lead the Stampede
# 0.014 Temple Garden
# 0.013 Blooming Marsh
# 0.013 Reclamation Sage
# 0.012 Eidolon of Rhetoric
# 0.012 Kataki, War's Wage
# 0.012 Stony Silence
# 0.012 Selfless Spirit
# 0.011 Fracturing Gust
# 0.011 Wooded Foothills
# 0.010 Chameleon Colossus
# 0.009 Overgrown Tomb
# 0.009 Burrenton Forge-Tender
